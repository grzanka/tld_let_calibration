# %% [markdown]
# # Imports

# %%
import pathlib

# install additional packages if running on Emscripten
import platform

import matplotlib
import pandas as pd

# %%
notebook_platform = platform.uname()
if notebook_platform.system == "Emscripten":
    import piplite

    await piplite.install("openpyxl")

# %% [markdown]
# # Data

# %%
this_file = pathlib.Path().absolute()
data_dir = this_file.parent / "data"
data_dir
# Out:
# WindowsPath('c:/Users/Legion/workspace/tld_let_calibration/data')

# %%
df_mcp = pd.read_excel(
    data_dir / "interim" / "Wyniki_DK_IFJ.xlsx", sheet_name="10.10.23_mts"
)
df_mcp
# Out:
#    Co_60_1Gy      ID    GlobalMaxX  GlobalMaxY  LocalMaxX  LocalMaxY  \
# 0         NaN    NaN           NaN         NaN        NaN        NaN
# 1   70_78.dat  220.0  1.989979e+06       100.0      240.0      220.0
# 2   69_77.dat  220.0  1.942963e+06       100.0      240.0      220.0
# 3   68_76.dat  220.0  1.964171e+06       100.0      240.0      220.0
# 4   67_75.dat  220.0  1.919291e+06       100.0      240.0      220.0
# ..        ...    ...           ...         ...        ...        ...
# 78    4_6.dat  220.0  2.166345e+06       100.0      240.0      220.0
# 79    3_5.dat  220.0  2.122013e+06       100.0      240.0      220.0
# 80    2_4.dat  220.0  2.138233e+06       100.0      240.0      220.0
# 81    1_3.dat  220.0  2.250345e+06       100.0      240.0      220.0
# 82        NaN    NaN  2.067445e+06         NaN        NaN        NaN
#
#     Counts(Sum)    Integral  Counts(Sum).1 Unnamed: 9  ...      Co_60 MaxX.1  \
# 0           NaN         NaN            NaN        IRF  ...        NaN    NaN
# 1     1989979.0  86194945.5   6.094446e+07    0.96253  ...  70_78.dat  220.0
# 2     1942963.0  82952002.0   5.852717e+07   0.939789  ...  69_77.dat  220.0
# 3     1964171.0  83688043.0   5.903087e+07   0.950047  ...  68_76.dat  220.0
# 4     1919291.0  80914325.0   5.720246e+07   0.928339  ...  67_75.dat  220.0
# ..          ...         ...            ...        ...  ...        ...    ...
# 78    2166345.0  89243865.0   6.306340e+07   1.047837  ...    4_6.dat  220.0
# 79    2122013.0  87735642.5   6.215512e+07   1.026394  ...    3_5.dat  220.0
# 80    2138233.0  90247006.5   6.367378e+07   1.034239  ...    2_4.dat  220.0
# 81    2250345.0  93918561.0   6.624286e+07   1.088467  ...    1_3.dat  220.0
# 82          NaN         NaN   6.318024e+07        NaN  ...        NaN    NaN
#
#     GlobalMax.1  From.1   To.1  LocalMaxX.3  LocalMaxY.3  Integral.3  \
# 0           NaN     NaN    NaN          NaN          NaN         NaN
# 1     1989979.0   248.0  310.0        276.0     159985.0   7340815.5
# 2     1942963.0   248.0  310.0        280.0     161923.0   7334337.0
# 3     1964171.0   248.0  310.0        279.0     163942.0   7394267.5
# 4     1919291.0   248.0  310.0        279.0     157456.0   7125667.5
# ..          ...     ...    ...          ...          ...         ...
# 78    2166345.0   248.0  310.0        277.0     174048.0   7683393.0
# 79    2122013.0   248.0  310.0        278.0     168931.0   7665339.0
# 80    2138233.0   248.0  310.0        279.0     173461.0   7701068.0
# 81    2250345.0   248.0  310.0        278.0     174449.0   7965713.5
# 82          NaN     NaN    NaN          NaN          NaN         NaN
#
#         Sum.1 Ɛ/δ(gamma)
# 0         NaN        NaN
# 1   5258434.0   3.688891
# 2   5258691.0   3.774821
# 3   5297097.0   3.764574
# 4   5075923.0   3.712656
# ..        ...        ...
# 78  5455824.0   3.546708
# 79  5457550.0   3.612296
# 80  5509592.0   3.601604
# 81  5687361.0   3.539774
# 82        NaN   3.625864
#
# [83 rows x 47 columns]

# %%
df_mcp.plot(y=["Integral", "Integral.1"])
# Out:
# <Axes: >

# %%
df_mcp.plot(y=["Eff"], grid=True)
# Out:
# <Axes: >
